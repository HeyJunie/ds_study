# %% [markdown]
# # 05. forecast(시계열 분석)

# %% [markdown]
# ## 1. 배경 및 설치

# %% [markdown]
# - fbprophet
#     - https://facebook.github.io/prophet/
# - mac(m1)
#     - 윈도우 유저는 visual C++ Build Tool을 먼저 설치한다.
#     - https://visualstudio.microsoft.com/ko/visual-cpp-build-tools/
#     - conda install pandas-datareader
#     - conda install -c conda-forge fbprophet
#     - pip install fbprophet

# %%
from pandas_datareader import data
from fbprophet import Prophet

# %% [markdown]
# ---

# %% [markdown]
# ## 함수(def)의 기초

# %%
def test_def(a, b):
    return a + b

# %%
c = test_def(2, 3)
c
# Out:
# 5

# %%
5 + c
# Out:
# 10

# %% [markdown]
# - 가장 기초적인 모양의 def 정의
# - 이름(test_def)과 같이 입력 인자(a, b)를 정해준다.
# - 출력(return)을 작성

# %%
#  전역변수(global)
a = 1
def edt_a(i):
    # 지역변수(local)
    global a
    a = i

# %%
edt_a(2)
a
# Out:
# 2

# %% [markdown]
# - global 변수를 def 내에서 사용하고 싶다면 global 로 선언

# %%
def edit_a(i):
    a = i

# %%
edit_a(5)
print(a)
# Out:
# 2

# %% [markdown]
# - def 내에서의 변수롸 밖에서의 변수는 같은 이름이어도 같은 것이 아니다.

# %% [markdown]
# $$ y = asin(2\pi ft + t_0) + b$$

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def plotSinWave(amp, freq, endTime, sampleTime, startTime, bias):
    """
    plot sine wave
    y = a sin(2 pi f t + t_0) + b
    """
    
    time = np.arange(startTime, endTime, sampleTime)
    result = amp * np.sin(2 * np.pi * freq * time + startTime) + bias
    
    plt.figure(figsize=(12, 6))
    plt.plot(time, result)
    plt.grid(True)
    plt.xlabel("time")
    plt.ylabel("sin")
    plt.title(str(amp) + "sin(2*pi)" + str(freq) + "*t+" + str(startTime) + ")" + str(bias))
    plt.show()

# %%
plotSinWave(2, 1, 10, 0.01, 0.5, 0)

# %%
def plotSinWave(**kwargs):
    """
    plot sine wave
    y = a sin(2 pi f t + t_0) + b
    """
    endTime = kwargs.get("endTime", 1)
    sampleTime = kwargs.get("sampleTime", 0.01)
    amp = kwargs.get("amp", 1)
    freq = kwargs.get("freq", 1)
    startTime = kwargs.get("startTime", 0)
    bias = kwargs.get("bias", 0)
    figsize = kwargs.get("figsize", (12, 6))
    
    time = np.arange(startTime, endTime, sampleTime)
    result = amp * np.sin(2 * np.pi * freq * time + startTime) + bias
    
    plt.figure(figsize=(12, 6))
    plt.plot(time, result)
    plt.grid(True)
    plt.xlabel("time")
    plt.ylabel("sin")
    plt.title(str(amp) + "sin(2*pi)" + str(freq) + "*t+" + str(startTime) + ")" + str(bias))
    plt.show()

# %%
plotSinWave()

# %% [markdown]
# ## 내가 만든 함수 import
# - drawSinWave.py

# %%
# %%writefile ./drawSinWave.py

import matplotlib.pyplot as plt
import numpy as np

def plotSinWave(**kwargs):
    """
    plot sine wave
    y = a sin(2 pi f t + t_0) + b
    """
    endTime = kwargs.get("endTime", 1)
    sampleTime = kwargs.get("sampleTime", 0.01)
    amp = kwargs.get("amp", 1)
    freq = kwargs.get("freq", 1)
    startTime = kwargs.get("startTime", 0)
    bias = kwargs.get("bias", 0)
    figsize = kwargs.get("figsize", (12, 6))
    
    time = np.arange(startTime, endTime, sampleTime)
    result = amp * np.sin(2 * np.pi * freq * time + startTime) + bias
    
    plt.figure(figsize=(12, 6))
    plt.plot(time, result)
    plt.grid(True)
    plt.xlabel("time")
    plt.ylabel("sin")
    plt.title("한글 테스트" + str(amp) + "sin(2*pi)" + str(freq) + "*t+" + str(startTime) + ")" + str(bias))
    plt.show()
# Out:
# Overwriting ./drawSinWave.py

# %%
import drawSinWave as dS

# %%
dS.plotSinWave()

# %%
dS.plotSinWave(freq = 5)

# %% [markdown]
# ## 그래프 한글 설정

# %%
# %%writefile ./set_matplotlib_hangul.py
import platform
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

if platform.system() == "Windows":# Window
    plt.rc("font", family= "Malgun Gothic")
elif platform.system() == 'Darwin': # Mac
    plt.rc("font", family= "Malgun Gothic")
else: #linux
    plt.rc("font", family= "NanumGothic")

# 그래프에 마이너스 표시가 되도록 변경
plt.rcParams['axes.unicode_minus'] = False
# Out:
# Overwriting ./set_matplotlib_hangul.py

# %%
import set_matplotlib_hangul

# %%
plt.title("한글")
# Out:
# Text(0.5, 1.0, '한글')

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Fbprophet 기초

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1.

# %%
time = np.linspace(0, 1, 365*2)
result = np.sin(2*np.pi*12*time)
ds = pd.date_range("2018-01-01", periods=365*2, freq="D")
df = pd.DataFrame({"ds":ds, "y":result})

# %%
df.head()
# Out:
#           ds         y
# 0 2018-01-01  0.000000
# 1 2018-01-02  0.103243
# 2 2018-01-03  0.205382
# 3 2018-01-04  0.305326
# 4 2018-01-05  0.402007

# %%
df["y"].plot(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
from fbprophet import Prophet

m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
m.plot(forecast);

# %% [markdown]
# #### 2.

# %%
time = np.linspace(0, 1, 365*2)
result = np.sin(2*np.pi*12*time) + time

ds = pd.date_range("2018-01-01", periods=365*2, freq="D")
df = pd.DataFrame({"ds":ds, "y":result})

df["y"].plot(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df)
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
m.plot(forecast);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %% [markdown]
# #### 3.

# %%
time = np.linspace(0, 1, 365*2)
result = np.sin(2*np.pi*12*time) + time + np.random.randn(365*2)/4

ds = pd.date_range("2018-01-01", periods=365*2, freq="D")
df = pd.DataFrame({"ds":ds, "y":result})

df["y"].plot(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df)
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
m.plot(forecast);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %% [markdown]
# ---

# %% [markdown]
# ## 3.시계열 데이터 실전 보기

# %% [markdown]
# - https://pinkwink.kr/

# %%
import pandas as pd
import pandas_datareader as web
import numpy as np
import matplotlib.pyplot as plt

from fbprophet import Prophet
from datetime import datetime

# %matplotlib inline

# %%
pinkwink_web = pd.read_csv(
    "./data/05_PinkWink_Web_Traffic.csv", 
    encoding="utf-8", 
    thousands=",", 
    names=["date", "hit"],
    index_col=0
)
pinkwink_web = pinkwink_web[pinkwink_web["hit"].notnull()]
pinkwink_web.head()
# Out:
#              hit
# date
# 16. 7. 1.  766.0
# 16. 7. 2.  377.0
# 16. 7. 3.  427.0
# 16. 7. 4.  902.0
# 16. 7. 5.  850.0

# %%
# 전체 데이터 그려보기
pinkwink_web["hit"].plot(figsize=(12, 6), grid=True)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# trend 분석을 시각화하기 위한 x축 값을 만들기
time = np.arange(0, len(pinkwink_web))
traffic = pinkwink_web["hit"].values
fx = np.linspace(0,time[-1], 1000)

# %%
# 에러를 계산할 함수
def error(f, x, y):
    return np.sqrt(np.mean((f(x) - y)) ** 2)

# %%
fp1 = np.polyfit(time, traffic, 1)
f1 = np.poly1d(fp1)

fp2 = np.polyfit(time, traffic, 2)
f2 = np.poly1d(fp2)

fp3 = np.polyfit(time, traffic, 3)
f3 = np.poly1d(fp3)

fp15 = np.polyfit(time, traffic, 15)
f15 = np.poly1d(fp15)

# %%
print(error(f1, time, traffic))
print(error(f2, time, traffic))
print(error(f3, time, traffic))
print(error(f15, time, traffic))
# Out:
# 3.687814133216257e-13
# 4.086496742212609e-13
# 2.691107610725377e-13
# 6.318839484253022e-06

# %%
plt.figure(figsize=(12, 4))
plt.scatter(time, traffic, s=10)
plt.plot(fx, f1(fx), lw=4, label="f1")
plt.plot(fx, f2(fx), lw=4, label="f2")
plt.plot(fx, f3(fx), lw=4, label="f3")
plt.plot(fx, f15(fx), lw=4, label="f15")

plt.grid(True, linestyle="-", color="0.75")
plt.legend(loc=2)
plt.show()

# %%
df = pd.DataFrame({"ds":pinkwink_web.index, "y":pinkwink_web["hit"]})
df.reset_index(inplace=True)
df["ds"] = pd.to_datetime(df["ds"], format="%y. %m. %d.")
del df["date"]
df.head()
# Out:
#           ds      y
# 0 2016-07-01  766.0
# 1 2016-07-02  377.0
# 2 2016-07-03  427.0
# 3 2016-07-04  902.0
# 4 2016-07-05  850.0

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
# 60일에 해당하는 데이터 예측
future = m.make_future_dataframe(periods=60)
future.tail()
# Out:
#             ds
# 420 2017-08-25
# 421 2017-08-26
# 422 2017-08-27
# 423 2017-08-28
# 424 2017-08-29

# %%
# 예측 결과는 상한/하한의 범위를 포함해서 얻어진다.
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#             ds         yhat   yhat_lower   yhat_upper
# 420 2017-08-25   896.576571   673.852444  1103.244249
# 421 2017-08-26   481.544412   265.288569   708.847034
# 422 2017-08-27   614.212001   418.354839   824.458218
# 423 2017-08-28  1166.966207   966.983461  1382.915119
# 424 2017-08-29  1203.000155  1005.732191  1412.207882

# %%
m.plot(forecast)

# %%
m.plot_components(forecast);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %% [markdown]
# ---

# %% [markdown]
# ## 4. 주식 데이터 fbprophet으로 분석하기

# %% [markdown]
# #### 1. yahoo finance
# - https://finance.yahoo.com/quote/035420.KS/history?p=035420.KS&guccounter=1

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request

url = "https://finance.yahoo.com/quote/035420.KS/history?p=035420.KS&guccounter=1"
req = Request(url, headers={"User-Agent":"Chrome"})
page = urlopen(req).read()
soup = BeautifulSoup(page, "html.parser")
table = soup.find("table")
df_raw = pd.read_html(str(table))[0]
df_raw.head()
# Out:
#            Date       Open       High        Low     Close* Adj Close**  Volume
# 0  Apr 11, 2022  311000.00  313000.00  308000.00  313000.00   313000.00  502976
# 1  Apr 08, 2022  322000.00  324500.00  311500.00  316500.00   316500.00  626173
# 2  Apr 07, 2022  323000.00  328500.00  321000.00  321000.00   321000.00  493204
# 3  Apr 06, 2022  336500.00  338000.00  329000.00  330000.00   330000.00  647201
# 4  Apr 05, 2022  340500.00  343000.00  338000.00  342500.00   342500.00  389951

# %%
# fbprophet을 사용하는 형식에 맞춰준 뒤, 맨 마지막 NaN 값이 있어서 제외
df_tmp = pd.DataFrame({"ds":df_raw["Date"], "y":df_raw["Close*"]})
df_target = df_tmp[:-1]
df_target.head()
# Out:
#              ds          y
# 0  Apr 11, 2022  313000.00
# 1  Apr 08, 2022  316500.00
# 2  Apr 07, 2022  321000.00
# 3  Apr 06, 2022  330000.00
# 4  Apr 05, 2022  342500.00

# %%
# hardcopy 후, 날짜를 fbprophet이 요구하는 형태로 변형
df = df_target.copy()
df["ds"] = pd.to_datetime(df_target["ds"], format="%b %d, %Y")
df.head()
# Out:
#           ds          y
# 0 2022-04-11  313000.00
# 1 2022-04-08  316500.00
# 2 2022-04-07  321000.00
# 3 2022-04-06  330000.00
# 4 2022-04-05  342500.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      100 non-null    datetime64[ns]
#  1   y       100 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.7+ KB

# %%
# 데이터형 변환 object => float
df["y"] = df["y"].astype("int")
df['y'][df['y'] == '511 Dividend'] = '350005.0505'
# df = df.astype({"y":"float"})
# Out:
# C:\Users\ThinkBook\AppData\Local\Temp\ipykernel_28984\1333077991.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y'][df['y'] == '511 Dividend'] = '350005.0505'

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds      yhat  yhat_lower  yhat_upper
# 2888 2016-01-26  7.700318    7.269212    8.174710
# 2889 2016-01-27  7.688848    7.230361    8.162813
# 2890 2016-01-28  7.644739    7.178042    8.090957
# 2891 2016-01-29  7.548879    7.114463    7.989002
# 2892 2016-01-30  7.249024    6.820673    7.699318

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["ds"], df["y"], label="real")
plt.grid(True)
plt.show()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
m.plot_components(forecast);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %% [markdown]
# ### 2. KIA

# %% [markdown]
# - pip install yfinance

# %%
# 기아 자동차의 종목코드를 가지고 기간으 입력한다.
import yfinance as yf
from pandas_datareader import data

yf.pdr_override()

start_date = "2010-03-01"
end_date = "2018-02-28"
KIA = data.get_data_yahoo("000270.KS", start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
KIA.head()
# Out:
#                Open     High      Low    Close     Adj Close   Volume
# Date
# 2010-03-02  22050.0  22300.0  21800.0  21850.0  17168.685547  3935516
# 2010-03-03  22100.0  22450.0  21850.0  22400.0  17600.849609  4380617
# 2010-03-04  22400.0  22600.0  22300.0  22500.0  17679.421875  2490087
# 2010-03-05  22500.0  22750.0  22350.0  22750.0  17875.861328  2379282
# 2010-03-08  23050.0  23100.0  22500.0  22800.0  17915.152344  4326618

# %%
KIA["Close"].plot(figsize=(12, 6), grid=True);

# %%
# accuracy 확인을 위한 데이터
KIA_trunc = KIA[:"2017-11-30"]
KIA_trunc.head()
# Out:
#                Open     High      Low    Close     Adj Close   Volume
# Date
# 2010-03-02  22050.0  22300.0  21800.0  21850.0  17168.685547  3935516
# 2010-03-03  22100.0  22450.0  21850.0  22400.0  17600.849609  4380617
# 2010-03-04  22400.0  22600.0  22300.0  22500.0  17679.421875  2490087
# 2010-03-05  22500.0  22750.0  22350.0  22750.0  17875.861328  2379282
# 2010-03-08  23050.0  23100.0  22500.0  22800.0  17915.152344  4326618

# %%
# forecast를 위한 준비
df = pd.DataFrame({"ds":KIA_trunc.index, "y":KIA_trunc["Close"]})
df.reset_index(inplace=True)
del df["Date"]
df.head()
# Out:
#           ds        y
# 0 2010-03-02  21850.0
# 1 2010-03-03  22400.0
# 2 2010-03-04  22500.0
# 3 2010-03-05  22750.0
# 4 2010-03-08  22800.0

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds          yhat    yhat_lower    yhat_upper
# 2003 2018-02-24  26941.910838  22835.352203  31230.793393
# 2004 2018-02-25  27027.517307  23035.656335  31122.530494
# 2005 2018-02-26  27228.793939  22853.184999  31342.317249
# 2006 2018-02-27  27397.261872  23225.726797  31655.815020
# 2007 2018-02-28  27444.142597  23446.774746  31431.784043

# %%
m.plot(forecast);

# %%
m.plot_components(forecast);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
KIA["Close"]
# Out:
# Date
# 2010-03-02    21850.0
# 2010-03-03    22400.0
# 2010-03-04    22500.0
# 2010-03-05    22750.0
# 2010-03-08    22800.0
#                ...
# 2018-02-21    33850.0
# 2018-02-22    33650.0
# 2018-02-23    34000.0
# 2018-02-26    34200.0
# 2018-02-27    34450.0
# Name: Close, Length: 1975, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(KIA.index, KIA["Close"], label="real")
plt.plot(forecast["ds"], forecast["yhat"], label="forecast")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### 3. 대한항공

# %%
# 003490 대한항공

start_date = "2010-03-01"
end_date = "2018-02-28"
KoreanAir = data.get_data_yahoo("003490.KS", start_date, end_date)
KoreanAir.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close  Volume
# Date
# 2018-02-21  35350.0  35950.0  35150.0  35350.0  35167.996094  237279
# 2018-02-22  35050.0  35450.0  34800.0  35000.0  34819.800781  260174
# 2018-02-23  35200.0  35400.0  34550.0  35150.0  34969.027344  321125
# 2018-02-26  35300.0  35550.0  33600.0  33900.0  33725.460938  932870
# 2018-02-27  33900.0  34300.0  33650.0  33900.0  33725.460938  527398

# %%
KoreanAir["Close"].plot(figsize=(12, 6), grid=True);

# %%
# accuracy 데이터 분리
KoreanAir_trunc = KoreanAir[:"2017-11-30"]
KoreanAir_trunc.tail()
# Out:
#                Open     High      Low    Close     Adj Close  Volume
# Date
# 2017-11-24  32900.0  33250.0  32300.0  32500.0  32168.935547  530941
# 2017-11-27  32600.0  32800.0  31800.0  31850.0  31525.556641  472095
# 2017-11-28  32050.0  32500.0  31550.0  31600.0  31278.103516  708754
# 2017-11-29  31850.0  32250.0  31050.0  31300.0  30981.160156  850385
# 2017-11-30  31800.0  32050.0  31350.0  31350.0  31030.650391  682573

# %%
# forecast를 위한 준비
df = pd.DataFrame({"ds":KoreanAir_trunc.index, "y":KoreanAir_trunc["Close"]})
df.reset_index(inplace=True)
del df["Date"]
df.head()
# Out:
#           ds             y
# 0 2010-03-02  59390.417969
# 1 2010-03-03  59190.785156
# 2 2010-03-04  59290.601562
# 3 2010-03-05  60588.207031
# 4 2010-03-08  62784.152344

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df)
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds          yhat    yhat_lower    yhat_upper
# 2003 2018-02-24  34885.595354  30458.791482  38795.322337
# 2004 2018-02-25  34790.953381  30702.787306  39088.920374
# 2005 2018-02-26  35763.113516  31714.745363  40121.891907
# 2006 2018-02-27  35606.628578  31206.335633  39686.227497
# 2007 2018-02-28  35527.670397  31033.345853  39888.842839

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
# 실제와 예측값을 비교 그래프
plt.figure(figsize=(12, 6))
plt.plot(KoreanAir.index, KoreanAir["Close"], label="real")
plt.plot(forecast["ds"], forecast["yhat"], label="forecast")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### 4. 조금 특이한 형태의 데이터에 대한 forecast

# %%
# Logistic 성장형 그래프를 가진 데이터에 대한 forecast
df = pd.read_csv("./data/05_example_wp_R2.csv", index_col=0)
df["y"].plot(figsize=(12, 4), grid=True)
# Out:
# <AxesSubplot:>

# %%
df["cap"] = 8.5
df.tail()
# Out:
#               ds         y  cap
# 2858  2015-12-11  7.834788  8.5
# 2859  2015-12-12  7.360104  8.5
# 2860  2015-12-13  7.479864  8.5
# 2861  2015-12-18  7.765145  8.5
# 2862  2015-12-19  7.220374  8.5

# %%
m = Prophet(growth="logistic", daily_seasonality=True)
m.fit(df);
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
future = m.make_future_dataframe(periods=1826)
future["cap"] = 8.5
forecast = m.predict(future)
m.plot(forecast)
# Out:
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Anaconda3\envs\ds_study\lib\site-packages\fbprophet\forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %% [markdown]
# ## 5. 비트코인 데이터 fbpophet으로 분석하기
